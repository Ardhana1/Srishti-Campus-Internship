# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.8 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.8 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.8 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.8 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.8 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.8 MB 1.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.8 MB 500.1 kB/s eta 0:00:18
#    ---- ----------------------------------- 1.0/9.8 MB 500.1 kB/s eta 0:00:18
#    ----- ---------------------------------- 1.3/9.8 MB 504.4 kB/s eta 0:00:17
# ...

# %%
import pandas as pd

# %%
#creating data frames

# %%
# from dictionary
data={'Name':['Alice','Bob'],'Age':[25,30]}

# %%
df=pd.DataFrame(data)

# %%
#from list of lists

# %%
list=[['Alice',25],['Bob',30]]

# %%
df = pd.DataFrame(list, columns=['Name', 'Age'])

# %%
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
#inspecting data

# %%
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
#Selecting Data

# %%
#Column selection

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: str

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
#Row selection

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
#Filtering data

# %%
df[df['Age']>25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
#Adding or removing columns

# %%
df['Gender']=['F','M']

# %%
df.drop('Age',axis=1,inplace=True)

# %%
print(df)
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
#Handling missing data

# %%
df.isnull()
# Out:
#     Name  Gender
# 0  False   False
# 1  False   False

# %%
df.dropna()
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.fillna(0)
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df['Age']=[25,30]

# %%
#Grouping and aggregating

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# F    25.0
# M    30.0
# Name: Age, dtype: float64

# %%
print(df)
df1=df
# Out:
#     Name Gender  Age
# 0  Alice      F   25
# 1    Bob      M   30

# %%
data={'NAME':['Afra','Gopika'],'GENDER':['F','F'],'AGE':[21,21]}
df2=pd.DataFrame(data)

# %%
#merge

# %%
pd.merge(df1,df2,on='Gender')
# Out:
#   Name_x Gender  Age_x  Name_y  Age_y
# 0  Alice      F     25    Afra     21
# 1  Alice      F     25  Gopika     21

# %%
df1.join(df2)
# Out:
#     Name Gender  Age    NAME GENDER  AGE
# 0  Alice      F   25    Afra      F   21
# 1    Bob      M   30  Gopika      F   21

# %%
# read csv

# %%
df=pd.read_csv("C:/Users/Ardhra/Downloads/50_Startups.csv")

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#write csv
df.to_csv('output.csv', index=False)

# %%
df.sort_values('State')
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 49       0.00       116983.80         45173.06  California   14681.40
# 42   23640.93        96189.63        148001.11  California   71498.49
# 40   28754.33       118546.05        172795.67  California   78239.91
# 34   46426.07       157693.92        210797.67  California   96712.80
# 16   78013.11       121597.55        264346.06  California  126992.93
# 44   22177.74       154806.14         28334.72  California   65200.33
# 25   64664.71       139553.16        137962.62  California  107404.34
# 13   91992.39       135495.07        252664.93  California  134307.35
# 11  100671.96        91790.61        249744.55  California  144259.40
# 20   76253.86       113867.30        298664.47  California  118474.03
# 39   38558.51        82982.09        174999.30  California   81005.76
# 6   134615.46       147198.87        127716.82  California  156122.51
# ...

# %%
df['R&D Spend'].apply(lambda x: x + 1)
# Out:
# 0     165350.20
# 1     162598.70
# 2     153442.51
# 3     144373.41
# 4     142108.34
# 5     131877.90
# 6     134616.46
# 7     130299.13
# 8     120543.52
# 9     123335.88
# 10    101914.08
# 11    100672.96
# 12     93864.75
# 13     91993.39
# 14    119944.24
# 15    114524.61
# 16     78014.11
# 17     94658.16
# 18     91750.16
# 19     86420.70
# 20     76254.86
# 21     78390.47
# 22     73995.56
# 23     67533.53
# 24     77045.01
# 25     64665.71
# 26     75329.87
# 27     72108.60
# 28     66052.52
# 29     65606.48
# 30     61995.48
# 31     61137.38
# 32     63409.86
# 33     55494.95
# 34     46427.07
# 35     46015.02
# 36     28664.76
# 37     44070.95
# 38     20230.59
# 39     38559.51
# 40     28755.33
# 41     27893.92
# 42     23641.93
# 43     15506.73
# 44     22178.74
# 45      1001.23
# 46      1316.46
# 47         1.00
# 48       543.05
# 49         1.00
# Name: R&D Spend, dtype: float64

# %%
df['State'].unique()
# Out:
# <StringArray>
# ['New York', 'California', 'Florida']
# Length: 3, dtype: str

# %%
df['R&D Spend'].value_counts()
# Out:
# R&D Spend
# 0.00         2
# 165349.20    1
# 162597.70    1
# 153441.51    1
# 144372.41    1
# 142107.34    1
# 131876.90    1
# 134615.46    1
# 130298.13    1
# 120542.52    1
# 123334.88    1
# 101913.08    1
# 100671.96    1
# 93863.75     1
# 91992.39     1
# 119943.24    1
# 114523.61    1
# 78013.11     1
# 94657.16     1
# 91749.16     1
# 86419.70     1
# 76253.86     1
# 78389.47     1
# 73994.56     1
# 67532.53     1
# 77044.01     1
# 64664.71     1
# 75328.87     1
# 72107.60     1
# 66051.52     1
# 65605.48     1
# 61994.48     1
# 61136.38     1
# 63408.86     1
# 55493.95     1
# 46426.07     1
# 46014.02     1
# 28663.76     1
# 44069.95     1
# 20229.59     1
# 38558.51     1
# 28754.33     1
# 27892.92     1
# 23640.93     1
# 15505.73     1
# 22177.74     1
# 1000.23      1
# 1315.46      1
# 542.05       1
# Name: count, dtype: int64
