# %%
#Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
iris=sns.load_dataset('iris')

# %%
iris.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()

# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.2 MB 2.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.2 MB 3.8 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.2 MB 3.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.2 MB 3.3 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.2 MB 3.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.7/8.2 MB 3.0 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.2 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.2 MB 2.7 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.2 MB 2.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.2 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.2 MB 2.5 MB/s eta 0:00:02
#    -------------------------- ------------- 5.5/8.2 MB 2.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.2 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.2 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.2 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.2 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.2 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 1.9 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/36.5 MB 606.3 kB/s eta 0:01:00
#     --------------------------------------- 0.8/36.5 MB 728.0 kB/s eta 0:00:50
#     --------------------------------------- 0.8/36.5 MB 728.0 kB/s eta 0:00:50
#    - -------------------------------------- 1.0/36.5 MB 739.6 kB/s eta 0:00:48
#    - -------------------------------------- 1.3/36.5 MB 780.9 kB/s eta 0:00:46
#    - -------------------------------------- 1.6/36.5 MB 855.9 kB/s eta 0:00:41
#    -- ------------------------------------- 1.8/36.5 MB 894.4 kB/s eta 0:00:39
#    -- ------------------------------------- 2.1/36.5 MB 931.7 kB/s eta 0:00:37
#    -- ------------------------------------- 2.4/36.5 MB 958.4 kB/s eta 0:00:36
#    -- ------------------------------------- 2.4/36.5 MB 958.4 kB/s eta 0:00:36
#    -- ------------------------------------- 2.6/36.5 MB 954.1 kB/s eta 0:00:36
#    --- ------------------------------------ 2.9/36.5 MB 918.6 kB/s eta 0:00:37
#    --- ------------------------------------ 2.9/36.5 MB 918.6 kB/s eta 0:00:37
#    --- ------------------------------------ 3.1/36.5 MB 912.9 kB/s eta 0:00:37
#    --- ------------------------------------ 3.4/36.5 MB 898.1 kB/s eta 0:00:37
#    --- ------------------------------------ 3.4/36.5 MB 898.1 kB/s eta 0:00:37
#    ---- ----------------------------------- 3.7/36.5 MB 908.2 kB/s eta 0:00:37
#    ---- ----------------------------------- 3.9/36.5 MB 921.9 kB/s eta 0:00:36
#    ---- ----------------------------------- 4.2/36.5 MB 912.0 kB/s eta 0:00:36
#    ---- ----------------------------------- 4.2/36.5 MB 912.0 kB/s eta 0:00:36
#    ---- ----------------------------------- 4.5/36.5 MB 905.6 kB/s eta 0:00:36
#    ----- ---------------------------------- 4.7/36.5 MB 909.1 kB/s eta 0:00:35
#    ----- ---------------------------------- 5.0/36.5 MB 918.6 kB/s eta 0:00:35
#    ----- ---------------------------------- 5.2/36.5 MB 936.6 kB/s eta 0:00:34
#    ------ --------------------------------- 5.5/36.5 MB 934.9 kB/s eta 0:00:34
#    ------ --------------------------------- 5.5/36.5 MB 934.9 kB/s eta 0:00:34
#    ------ --------------------------------- 5.8/36.5 MB 928.6 kB/s eta 0:00:34
#    ------ --------------------------------- 6.0/36.5 MB 928.5 kB/s eta 0:00:33
#    ------ --------------------------------- 6.3/36.5 MB 946.6 kB/s eta 0:00:32
#    ------- -------------------------------- 6.6/36.5 MB 961.5 kB/s eta 0:00:32
#    ------- -------------------------------- 6.8/36.5 MB 961.0 kB/s eta 0:00:31
#    ------- -------------------------------- 7.1/36.5 MB 962.2 kB/s eta 0:00:31
#    -------- ------------------------------- 7.3/36.5 MB 971.5 kB/s eta 0:00:31
#    -------- ------------------------------- 7.6/36.5 MB 979.7 kB/s eta 0:00:30
#    -------- ------------------------------- 7.9/36.5 MB 997.7 kB/s eta 0:00:29
#    --------- ------------------------------ 8.4/36.5 MB 1.0 MB/s eta 0:00:28
#    --------- ------------------------------ 8.7/36.5 MB 1.0 MB/s eta 0:00:27
#    --------- ------------------------------ 8.9/36.5 MB 1.0 MB/s eta 0:00:27
#    ---------- ----------------------------- 9.2/36.5 MB 1.0 MB/s eta 0:00:27
#    ---------- ----------------------------- 9.4/36.5 MB 1.1 MB/s eta 0:00:26
#    ---------- ----------------------------- 9.7/36.5 MB 1.1 MB/s eta 0:00:26
#    ----------- ---------------------------- 10.2/36.5 MB 1.1 MB/s eta 0:00:25
#    ----------- ---------------------------- 10.5/36.5 MB 1.1 MB/s eta 0:00:24
#    ----------- ---------------------------- 10.7/36.5 MB 1.1 MB/s eta 0:00:24
#    ------------ --------------------------- 11.3/36.5 MB 1.1 MB/s eta 0:00:23
#    ------------ --------------------------- 11.5/36.5 MB 1.1 MB/s eta 0:00:23
#    ------------ --------------------------- 11.8/36.5 MB 1.1 MB/s eta 0:00:23
#    ------------- -------------------------- 12.1/36.5 MB 1.1 MB/s eta 0:00:22
#    ------------- -------------------------- 12.3/36.5 MB 1.1 MB/s eta 0:00:22
#    ------------- -------------------------- 12.6/36.5 MB 1.1 MB/s eta 0:00:22
#    -------------- ------------------------- 13.1/36.5 MB 1.2 MB/s eta 0:00:21
#    -------------- ------------------------- 13.4/36.5 MB 1.2 MB/s eta 0:00:20
#    -------------- ------------------------- 13.6/36.5 MB 1.2 MB/s eta 0:00:20
#    --------------- ------------------------ 13.9/36.5 MB 1.2 MB/s eta 0:00:20
#    --------------- ------------------------ 14.2/36.5 MB 1.2 MB/s eta 0:00:20
#    ---------------- ----------------------- 14.7/36.5 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 15.5/36.5 MB 1.2 MB/s eta 0:00:18
#    ----------------- ---------------------- 15.7/36.5 MB 1.2 MB/s eta 0:00:17
#    ----------------- ---------------------- 16.3/36.5 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 16.5/36.5 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 16.8/36.5 MB 1.2 MB/s eta 0:00:16
#    ------------------ --------------------- 17.3/36.5 MB 1.3 MB/s eta 0:00:16
#    ------------------- -------------------- 17.8/36.5 MB 1.3 MB/s eta 0:00:15
#    ------------------- -------------------- 18.1/36.5 MB 1.3 MB/s eta 0:00:15
#    -------------------- ------------------- 18.6/36.5 MB 1.3 MB/s eta 0:00:14
#    -------------------- ------------------- 18.9/36.5 MB 1.3 MB/s eta 0:00:14
#    --------------------- ------------------ 19.4/36.5 MB 1.3 MB/s eta 0:00:14
#    --------------------- ------------------ 19.7/36.5 MB 1.3 MB/s eta 0:00:13
#    --------------------- ------------------ 19.9/36.5 MB 1.3 MB/s eta 0:00:13
#    ---------------------- ----------------- 20.2/36.5 MB 1.3 MB/s eta 0:00:13
#    ---------------------- ----------------- 20.7/36.5 MB 1.3 MB/s eta 0:00:12
#    ----------------------- ---------------- 21.2/36.5 MB 1.3 MB/s eta 0:00:12
#    ----------------------- ---------------- 21.5/36.5 MB 1.3 MB/s eta 0:00:12
#    ------------------------ --------------- 22.0/36.5 MB 1.4 MB/s eta 0:00:11
#    ------------------------ --------------- 22.3/36.5 MB 1.4 MB/s eta 0:00:11
#    ------------------------ --------------- 22.5/36.5 MB 1.4 MB/s eta 0:00:11
#    ------------------------- -------------- 23.1/36.5 MB 1.4 MB/s eta 0:00:10
#    ------------------------- -------------- 23.6/36.5 MB 1.4 MB/s eta 0:00:10
#    -------------------------- ------------- 24.1/36.5 MB 1.4 MB/s eta 0:00:09
#    -------------------------- ------------- 24.4/36.5 MB 1.4 MB/s eta 0:00:09
#    --------------------------- ------------ 24.9/36.5 MB 1.4 MB/s eta 0:00:09
#    --------------------------- ------------ 25.2/36.5 MB 1.4 MB/s eta 0:00:09
#    ---------------------------- ----------- 25.7/36.5 MB 1.4 MB/s eta 0:00:08
#    ---------------------------- ----------- 26.2/36.5 MB 1.4 MB/s eta 0:00:08
#    ----------------------------- ---------- 26.7/36.5 MB 1.4 MB/s eta 0:00:07
#    ----------------------------- ---------- 27.3/36.5 MB 1.4 MB/s eta 0:00:07
#    ------------------------------ --------- 27.5/36.5 MB 1.4 MB/s eta 0:00:07
#    ------------------------------ --------- 27.8/36.5 MB 1.4 MB/s eta 0:00:07
#    ------------------------------- -------- 28.3/36.5 MB 1.5 MB/s eta 0:00:06
#    ------------------------------- -------- 28.6/36.5 MB 1.5 MB/s eta 0:00:06
#    ------------------------------- -------- 29.1/36.5 MB 1.5 MB/s eta 0:00:06
#    -------------------------------- ------- 29.4/36.5 MB 1.5 MB/s eta 0:00:05
#    -------------------------------- ------- 29.6/36.5 MB 1.5 MB/s eta 0:00:05
#    -------------------------------- ------- 29.9/36.5 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 30.1/36.5 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 30.4/36.5 MB 1.5 MB/s eta 0:00:05
#    --------------------------------- ------ 30.7/36.5 MB 1.4 MB/s eta 0:00:05
#    --------------------------------- ------ 30.9/36.5 MB 1.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 31.2/36.5 MB 1.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 31.5/36.5 MB 1.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 31.5/36.5 MB 1.4 MB/s eta 0:00:04
#    ---------------------------------- ----- 31.7/36.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 32.0/36.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 32.2/36.5 MB 1.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 32.5/36.5 MB 1.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.8/36.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 33.0/36.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 33.3/36.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------ --- 33.6/36.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 34.1/36.5 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------- -- 34.1/36.5 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------- -- 34.6/36.5 MB 1.4 MB/s eta 0:00:02
#    -------------------------------------- - 34.9/36.5 MB 1.4 MB/s eta 0:00:02
#    -------------------------------------- - 35.1/36.5 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.5 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  35.7/36.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  35.7/36.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 1.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, joblib, scikit-learn
#
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    ---------------------------------------- 5/5 [scikit-learn]
#
# Successfully installed joblib-1.5.3 narwhals-2.22.1 scikit-learn-1.9.0 scipy-1.17.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
type(iris_data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
iris_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
#feature names(variable names)
iris_data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
#dependend variables
iris_data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris_data['data']
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
iris_df=pd.DataFrame(data=iris_data['data'],columns=iris_data['feature_names'])
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris_df['Iris type']=iris_data['target']

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Iris type
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
from PIL import Image
img=Image.open(r"iris.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x367>

# %%
df=pd.read_csv('Iris_Data.csv')

# %%
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Dataset shape
print(f"Dataset shape:{iris.shape}")
#Basic info
iris.info()
# Out:
# Dataset shape:(150, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
#Statistical Summary
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#Check for missing value
print("\nMissing values per column")
print(iris.isnull().sum())
# Out:
# Missing values per column
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#Dataset Duplicate Value Count
dup=df.duplicated().sum()
print(f'number of duplicate rows are {dup}')
# Out:
# number of duplicate rows are 1

# %%
df.Species.value_counts()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
#Categorical encoding
#Library used for data preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
#Encode the categorical columns
#Create a label encoder object
le=LabelEncoder()
# Encode the 'Species' column to convert the species names to numerical labels
df['Species'] = le.fit_transform(df['Species'])
# Check the unique values in the 'Species' column after encoding
unique_species = df['Species'].unique()
# Display the unique encoded values
print("Encoded Species Values:")
print(unique_species) # 'Iris-setosa' == 0, 'Iris-versicolor' == 1, 'Iris virginica'== 2
# Out:
# Encoded Species Values:
# [0 1 2]

# %%
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
#Species distribution
print("\nSpecies distribution:")
print(iris['species'].value_counts())
# Out:
# Species distribution:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
#Univariate analysis
#Distribution of numerical features
#Create Subplots
fig, axes=plt.subplots(2,2,figsize=(15,10))
#plot distributions
sns.histplot(iris['sepal_length'],kde=True,ax=axes[0,0],color='green')
axes[0, 0].set_title('Sepal Length Distribution')
sns.histplot(iris['sepal_width'], kde=True, ax=axes[0, 1], color='skyblue')
axes[0, 1].set_title('Sepal Width Distribution')
sns.histplot(iris['petal_length'], kde=True, ax=axes[1, 0], color='orange')
axes[1, 0].set_title('Petal Length Distribution')
sns.histplot(iris['petal_width'], kde=True, ax=axes[1, 1], color='red')
axes[1, 1].set_title('Petal Width Distribution')
plt.tight_layout()
plt.show()

# %%
#Boxplots for numerical features
plt.figure(figsize=(12,6))
sns.boxplot(data=iris.drop('species',axis=1))
plt.title('Plot of all numerical Features')
plt.ylabel('Centimeters(cm)')
plt.show()

# %%
#default theme
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context='notebook', style='darkgrid', palette='colorblind', font='sans-serif', font_scale=1,rc=None)
matplotlib.rcParams['figure.figsize'] =[8,8]
matplotlib.rcParams.update({'font.size': 15})
matplotlib.rcParams['font.family'] = 'sans-serif'
sns.set_style('darkgrid')

# %%
sns.countplot(x='Species',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
df['Species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%'
,shadow=True, figsize=(10,8))
plt.show()

# %%
#Chart - 1 : Distribution of Numerical Variables
df.hist(edgecolor='black',figsize=(12,12))
plt.show()

# %%
#Chart - 1 : Histogram Visualization for Distribution of Numerical Variables
# Create a figure with Subplots
plt.figure(figsize=(8,6))
plt.suptitle('Distribution of Iris Flower Measurements', fontsize=14)
#Create 2x2 grid of subplots
plt.subplot(2,2,1)#Subplot 1 (Top_left)
plt.hist(df['Sepal.Length'])
plt.title('Sepal Length Distribution')

plt.subplot(2,2,2)#Subplot 2 (Top_right)
plt.hist(df['Sepal.Width'])
plt.title('Sepal Width Distribution')

plt.subplot(2,2,3)#Subplot 3 (Bottom_left)
plt.hist(df['Petal.Length'])
plt.title('Petal Length Distribution')

plt.subplot(2,2,4)#Subplot 4 (Bottom_right)
plt.hist(df['Petal.Width'])
plt.title('Petal Width Distribution')

# Display the subplots
plt.tight_layout() # Helps in adjusting the layout
plt.show()

# %%
# We can look at an individual feature in Seaborn through a boxplot
sns.boxplot(x="Species", y="Petal.Length", data=df)
# Out:
# <Axes: xlabel='Species', ylabel='Petal.Length'>

# %%
ax = sns.boxplot(x="Species", y="Petal.Length", data=df)
ax = sns.stripplot(x="Species", y="Petal.Length", data=df, jitter=True, edgecolor="gray")
# Out:
# C:\Users\Ardhra\AppData\Local\Temp\ipykernel_9560\3526364244.py:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x="Species", y="Petal.Length", data=df, jitter=True, edgecolor="gray")

# %%
#Bivariate Analysis
# Create the figure
plt.figure(figsize=(8, 6))
species = df['Species'].unique()
colors = ['red', 'green', 'blue']
# Scatter plot for each species
for i in range(len(species)):
 x = df[df['Species'] == species[i]]
 plt.scatter(x['Sepal.Length'], x['Sepal.Width'], c=colors[i], label=species[i])
# Add labels and legend
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs Width by Species')
plt.legend()
#Show plot
plt.show()

# %%
df.plot(kind="scatter", x="Sepal.Length", y="Sepal.Width")
# Out:
# <Axes: xlabel='Sepal.Length', ylabel='Sepal.Width'>

# %%
#Pairwise Relationships
sns.pairplot(df , hue='Species');

# %%
sns.pairplot(df , hue='Sepal.Width');

# %%
sns.pairplot(iris, hue='species', palette='viridis', height=2.5)
plt.suptitle('Pairwise Relationships by Species', y=1.02)
plt.show()

# %%
#Correlation Heatmap
# Calculate correlation
corr = iris.drop('species', axis=1).corr()
# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, fmt=".2f")
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
df.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width   Species
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941  0.782561
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126 -0.426658
# Petal.Length      0.871754    -0.428440      1.000000     0.962865  0.949035
# Petal.Width       0.817941    -0.366126      0.962865     1.000000  0.956547
# Species           0.782561    -0.426658      0.949035     0.956547  1.000000

# %%
df.iloc[:, :-1].corr().style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_ddb0b_row0_col0, #T_ddb0b_row1_col1, #T_ddb0b_row2_col2, #T_ddb0b_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ddb0b_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ddb0b_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_ddb0b_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_ddb0b_row1_col0, #T_ddb0b_row1_col2, #T_ddb0b_row1_col3, #T_ddb0b_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ddb0b_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_ddb0b_row2_col3, #T_ddb0b_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_ddb0b_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_ddb0b_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ddb0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddb0b_level0_col0" class="col_heading level0 col0" >Sepal.Length</th>
#       <th id="T_ddb0b_level0_col1" class="col_heading level0 col1" >Sepal.Width</th>
#       <th id="T_ddb0b_level0_col2" class="col_heading level0 col2" >Petal.Length</th>
#       <th id="T_ddb0b_level0_col3" class="col_heading level0 col3" >Petal.Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddb0b_level0_row0" class="row_heading level0 row0" >Sepal.Length</th>
#       <td id="T_ddb0b_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_ddb0b_row0_col1" class="data row0 col1" >-0.12</td>
#       <td id="T_ddb0b_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_ddb0b_row0_col3" class="data row0 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_ddb0b_level0_row1" class="row_heading level0 row1" >Sepal.Width</th>
#       <td id="T_ddb0b_row1_col0" class="data row1 col0" >-0.12</td>
#       <td id="T_ddb0b_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ddb0b_row1_col2" class="data row1 col2" >-0.43</td>
#       <td id="T_ddb0b_row1_col3" class="data row1 col3" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_ddb0b_level0_row2" class="row_heading level0 row2" >Petal.Length</th>
#       <td id="T_ddb0b_row2_col0" class="data row2 col0" >0.87</td>
#       <td id="T_ddb0b_row2_col1" class="data row2 col1" >-0.43</td>
#       <td id="T_ddb0b_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_ddb0b_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_ddb0b_level0_row3" class="row_heading level0 row3" >Petal.Width</th>
#       <td id="T_ddb0b_row3_col0" class="data row3 col0" >0.82</td>
#       <td id="T_ddb0b_row3_col1" class="data row3 col1" >-0.37</td>
#       <td id="T_ddb0b_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_ddb0b_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# Plot distributions by species
sns.boxplot(x='species', y='sepal_length', data=iris, ax=axes[0, 0], palette='Set2')
axes[0, 0].set_title('Sepal Length by Species')
sns.boxplot(x='species', y='sepal_width', data=iris, ax=axes[0, 1], palette='Set2')
axes[0, 1].set_title('Sepal Width by Species')
sns.boxplot(x='species', y='petal_length', data=iris, ax=axes[1, 0], palette='Set2')
axes[1, 0].set_title('Petal Length by Species')
sns.boxplot(x='species', y='petal_width', data=iris, ax=axes[1, 1], palette='Set2')
axes[1, 1].set_title('Petal Width by Species')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ardhra\AppData\Local\Temp\ipykernel_9560\1732504263.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_length', data=iris, ax=axes[0, 0], palette='Set2')
# C:\Users\Ardhra\AppData\Local\Temp\ipykernel_9560\1732504263.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_width', data=iris, ax=axes[0, 1], palette='Set2')
# C:\Users\Ardhra\AppData\Local\Temp\ipykernel_9560\1732504263.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal_length', data=iris, ax=axes[1, 0], palette='Set2')
# C:\Users\Ardhra\AppData\Local\Temp\ipykernel_9560\1732504263.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal_width', data=iris, ax=axes[1, 1], palette='Set2')

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='species', y='petal_length', data=iris, inner='quartile', palette='pastel')
plt.title('Petal Length Distribution by Species')
plt.show()
# Out:
# C:\Users\Ardhra\AppData\Local\Temp\ipykernel_9560\3742048603.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species', y='petal_length', data=iris, inner='quartile', palette='pastel')

# %%
#Advanced Visualizations
#Andrews Curves
from pandas.plotting import andrews_curves
plt.figure(figsize=(10, 6))
andrews_curves(iris, 'species', colormap='viridis')
plt.title('Andrews Curves for Iris Dataset')
plt.show()

# %%
#Parallel Coordinates
from pandas.plotting import parallel_coordinates
plt.figure(figsize=(10, 6))
parallel_coordinates(iris, 'species', colormap='viridis')
plt.title('Parallel Coordinates Plot for Iris Dataset')
plt.show()
