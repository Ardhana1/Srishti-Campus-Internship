# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\ardhra\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
arr=np.array([1,2,3])
print (arr)
# Out:
# [1 2 3]

# %%
arr_2d=np.array(([1,2,3],[4,5,6]))
print(arr_2d)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#Special Arrays

# %%
a=np.zeros((3,3))
print(a)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
a=np.ones((2,4))
print(a)
# Out:
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]

# %%
a=np.ones((2,4))
print(a)
# Out:
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]

# %%
a=np.eye((3))
print(a)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
a=np.arange(0,10,2)
print(a)
# Out:
# [0 2 4 6 8]

# %%
a=np.linspace(0,1,5)
print(a)
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
a=np.random.randn(3,2)
print(a)
# Out:
# [[-0.28402142  0.54055166]
#  [ 1.81550138  0.4565929 ]
#  [ 1.39008186 -1.1755947 ]]

# %%
a=np.random.rand(3,2)
print(a)
# Out:
# [[0.98929514 0.45411592]
#  [0.50403207 0.29362291]
#  [0.9303864  0.28051362]]

# %%
#Array Attributes

# %%
arr=np.array(([1,2,3],[4,5,6]))
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr.shape)
# Out:
# (2, 3)

# %%
print(arr.ndim)
# Out:
# 2

# %%
print(arr.size)
# Out:
# 6

# %%
print(arr.dtype)
# Out:
# int64

# %%
#Array Operations
a=np.array([1,2,3])
b=np.array([4,5,6])

# %%
a+b
# Out:
# array([5, 7, 9])

# %%
b-a
# Out:
# array([3, 3, 3])

# %%
a*b
# Out:
# array([ 4, 10, 18])

# %%
np.sin(a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
np.cos(a)
# Out:
# array([ 0.54030231, -0.41614684, -0.9899925 ])

# %%
#Matrix Multiplication
A=np.array([[1,2],[3,4]])

# %%
B=np.array([[5,6],[7,8]])
np.dot(A,B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A@B
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
#Aggregation
arr=np.array([1,2,3,4])
print(arr.sum())
# Out:
# 10

# %%
print(arr.mean())
# Out:
# 2.5

# %%
print(arr.min())
# Out:
# 1

# %%
print(arr.max())
# Out:
# 4

# %%
print(arr.std())
# Out:
# 1.118033988749895

# %%
#indexing and slicing
#1D Array

# %%
arr=np.array([1,2,3,4,5])
print(arr[0])
# Out:
# 1

# %%
print(arr[1:4])
# Out:
# [2 3 4]

# %%
print(arr[::2])
# Out:
# [1 3 5]

# %%
#2D arrays

# %%
arr=np.array([[1,2,3],[4,5,6]])
print(arr[1,1])
# Out:
# 5

# %%
print(arr[:,1])
# Out:
# [2 5]

# %%
print(arr[1,:3])
# Out:
# [4 5 6]

# %%
#Boolean Indexing
arr=np.array([1,2,3,4,5])

# %%
mask=arr<3

# %%
print(arr[mask])
# Out:
# [1 2]

# %%
#Reshaping and Combining Arrays
#Reshape
arr=np.arange(6)

# %%
print(arr.reshape(2,3))
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
#concatenation
a=np.array([1,2])
b=np.array([3,4])
np.concatenate((a,b))
# Out:
# array([1, 2, 3, 4])

# %%
#Stacking
np.vstack((a,b))
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.hstack((a,b))
# Out:
# array([1, 2, 3, 4])

# %%
a = np.array([1, 2, 3])
a + 5
# Out:
# array([6, 7, 8])

# %%
# Save to a file
np.save('array.npy', arr)

# %%
# Load from a file
loaded_arr = np.load('array.npy')
